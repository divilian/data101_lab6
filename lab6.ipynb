# %% [markdown]
# # Lab Six
# Welcome to DATA 101 lab six, an **individual OR partner** lab, your choice. Either way, it will be collected on **Friday, Dec. 4th at 11:59pm**. Good luck!

# %% [markdown]
# # Say hello to our studio audience
# In the cell below, create a **string** variable called `my_name` which has your full name. (If you're doing this lab with a partner, instead create a NumPy array called `our_names` with two strings in it.)

# %% [markdown]
# # Highly functioning
# Write a function called `triple_it()` that takes a single numeric argument (which you can name whatever you want), and returns triple its value. (For example, calling `triple_it(4)` should return the number 12.)
#
# (Needless to say, you should also make sure to write code to _test_ this function (_i.e._, call the function for a few sample values, and print the answer it returns) to verify it actually works.)

# %% [markdown]
# Write a function called `mpg()` that takes three arguments: `start_mileage`, which is the starting mileage on a car's odometer; `end_mileage`, which is the ending mileage on a car's odometer; and `gallons`, which is the number of gallons of gas it took to drive that distance. It should return the miles per gallon for the car.
#
# (Needless to say, you should also write code to test this function.)

# %% [markdown]
# Write a function called `lucky_add()` that takes two numeric arguments (which you can name whatever you want), and returns their sum, _unless_ their sum is 13, in which case it returns 0.
#
# (Needless to say, you should also write code to test it.)

# %% [markdown]
# Write a function called `salutation()` which takes three arguments: `gender` (`male`, `female`, or `other`), `marital_status` (`single`, `married`, `divorced`, or `widowed`), and `degree` (`None`, `AA`, `BA`, `BS`, `MA`, `MS`, or `PhD`). It should return the string `"Dr."` for Ph.D.'s, `"Mr."` for all other males, `"Mx."` for all people with "`other`" gender, `"Miss"` for single females, `"Mrs."` for married females, and `"Ms."` for other females. (Yes, we did this example in class and in the book. Try to do it yourself again without looking, though, and then look if you need to.)
#
# (Needless to say.)

# %% [markdown]
# In the U.S. tax code, a taxpayer's **AGI** (Adjusted Gross Income) is (basically) the sum of their year's wages and tips, minus any alimony they received and any retirement contributions they made. Write a function called `agi()` which takes four arguments -- a taxpayer's wages, tips, alimony, and retirement contributions -- and returns their AGI.
#
# As a courtesy, I have written the function header for you.
#
# (Needless to.)

# %%
def agi(wages, tips, alimony, ret_contrib):
    # Your code goes here
    return 0

# %% [markdown]
# In the U.S. tax code, a taxpayer's **taxable income** is their AGI minus their deductions. Deductions can be either "standard" or "itemized." For taxpayers who itemize their deductions, their deduction is simply the amount they itemized (duh). In 2019, the standard deduction (for non-itemizers) is either \$12,200 (for taxpayers less than 65 years old) or else \$14,000 (for those 65 years or older).
#
# Note that a taxpayer's taxable income is never less than zero. If the calculations described above would result in a negative taxable income, that taxpayer's taxable income is zero dollars, period.
#
# Write a function called `taxable_income()` that takes the arguments specified below. It should return the person's taxable income. (For itemized deductions equal to 0, use the taxpayer's standard deduction in the calculation. Otherwise, use their itemized deductions.)
#
# **Inside your code for the `taxable_income()` function, you should call your `agi()` function to help it do its work.**
#
# (Needless.)

# %%
def taxable_income(wages, tips, alimony, ret_contrib, deductions, year_of_birth):
    # Your code goes here
    return 0

# %% [markdown]
# # Polygraph
# The file `truths_or_lies.txt` contains some of the statements students gave as answers to the last lab. Read it into a NumPy array called `truths_or_lies`. There are 84 elements in it, exactly half of which are true and half of which are false.
#
# Create a NumPy array of 42 integers called `polygraph` that has *only the index numbers for the statements you think are the true ones.* Your score will be based on how many truths you correctly identify. Note that you are free to run the checker script multiple times to try and get a better score!
#
# Btw, you might find it handy to print out each element of this array along with its index number. You could do that with the following code:
#
# ```
# for i, t_or_l in enumerate(truths_or_lies):
#     print("Truth/lie #{}: {}".format(i, t_or_l))
# ```

# %% [markdown]
# # Check out my new 'do
# The file `haircuts.csv` gives the approximate number of haircuts each person in the class has undergone in their lifetime, together with their gender. (I made an educated guess at each student's gender when I assembled this data. If you do not identify with the male or female gender, or if you recognize your number but I got your gender wrong, please accept my sincere apologies, and know that I would be happy to learn about your gender if you would like to tell me about that sometime.)
#
# First, read this data in to a DataFrame called `haircuts`.
#
# Now I feel like some of these people are delusional. Consider: if a 20-year-old person had gotten a haircut every single week of their lives, how many total haircuts would they have had? Remove any (bogus) data points from the DataFrame that exceed that number.

# %% [markdown]
# Create a histogram showing the relative frequencies of the *number of haircuts per year* students in the class receive. To perform this calculation, you should assume that every student in the class is **exactly 20 years old**. Give the histogram an appropriate number of bins (experiment with this, as before).

# %% [markdown]
# Now create a grouped box plot showing the mens' and women's haircuts separately. Does this plot surprise you? (It did me!)

# %% [markdown]
# # Your thoughts betray you¶
# The file "`starwars.csv`" contains (fake) data about the various Jedi Knights and Sith Lords in the last thousand years or so of the Old Republic. Load this into a DataFrame called `starwars` and take a peek at it. Just leave the index as the default instead of specifying one of the columns. (As a matter of interest, a "Jedi" in the Star Wars universe is a "good guy," and a "Sith" is a "bad guy.")

# %% [markdown]
# As you can see, this data set contains **four** categorical features: `beard`, `height`, `demeanor`, and `lightsaber`. The target attribute (label) is called `type`.
#
# Our goal is to use this data set to build an intelligent control mechanism for our security system. If a probable Sith is detected on one of our security cameras, we want to sound the alarm and arrest him/her, whereas if the presence of a Jedi is detected, we want to carry on and take no action.
#
# To do this, we will build a Decision Tree classifier that will predict the Jedi-ness or Sith-ness of life forms who might appear on our cameras.
#
# First, let's get our feet wet by implementing a **sucky** classifier. Write a Python function called `sucky()` that takes four arguments: `beard`, `height`, `demeanor`, and `lightsaber`, in that order. It should return either the string "`Jedi`" or the string "`Sith`" according to the following (randomly-created, and not based at all on our training data) decision tree:
#
# <center>
# <img src="decisionTree.png" />
# </center>

# %% [markdown]
# Now let's just do some basic inspection of the `starwars` training set. Does the first person in this data set have a beard? Does the last? Set Python variables `first_hairy` and `last_hairy` to the **boolean** values `True` if so, and `False` if not.

# %% [markdown]
# What *percentage* of the people in this data set (on a 0-to-100 scale) are of *short* or *medium* stature? Store this percentage in a Python variable `comfortable_on_airplanes`.

# %% [markdown]
# What percentage of all people have menacing stares and wield blue lightsabers? Store this percentage in a Python variable `blue_menaces`.

# %% [markdown]
# What percentage *of the people with menacing stares* wield blue lightsabers? (Note this is a different question than the previous one.) Store this percentage in a Python variable `menaces_who_wield_blue`.

# %% [markdown]
# What percentage of bearded Jedi have calm demeanors? (Note that this question is asking specifically about *Jedi*, not persons in general.) Store this percentage in a Python variable `fuzzy_jedi_who_are_chill`.

# %% [markdown]
# ## _Extra credit_: inducing a decent Sith Detector
# Based on this data set, if you just used the prior, what would you predict a random individual to be: Jedi, or Sith? Put your answer in a string Python variable called `prior_guess`, and put the percentage (on a scale from 0.0 to 100.0) that you would get correct by guessing this in a float Python variable called `prior_percentage`.

# %% [markdown]
# Suppose you were to build a decision tree classifier that would predict whether a person was a Jedi or a Sith based on their facial hair, height, demeanor, and lightsaber color. Which feature would you split on first (*i.e.*, at the root)? Name that feature in a Python variable called `first_split` and put the percentage of training points that you would guess correctly if you stopped at that level in a variable `first_split_percentage`. (This problem will take some thinking and some calculation to answer.)

# %% [markdown]
# Figure out the *second* level of the decision tree -- *i.e.*, which of the remaining attributes you would split on next for *each* of the branches from the root. Take your time; this will require a few queries and calculations.
#
# Then, write a function called `predict()` which takes four arguments: `beard`, `height`, `demeanor`, and `lightsaber` (all strings). It should use a two-level decision tree to determine and return a string giving the predicted value: "`Jedi`" or "`Sith`".

# %% [markdown]
# # Check out
# Nice job! Now run the test script below to see if it all worked! (If not, go back and fix your errors.)

# %%
import requests
exec(requests.get("http://stephendavies.org/data101/lab6checker.py").content)
